# %% [markdown]
# # Projeto Python IA
#
# ### Case: Score de Crédito dos Clientes

# %%
# !pip install pandas  scikit-learn
# obs: kaggle para achar base de dados aleatórias

# Passo 1: Importar a base de dados
import pandas as pd

tabela = pd.read_csv('clientes.csv')
display(tabela)
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\gafeb\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 262.6 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 281.8 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.8 kB 292.6 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 231.8 kB/s eta 0:00:00
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
# ...

# %%
# verificar se tem algum problema com a base de dados
display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id_cliente                100000 non-null  int64
#  1   mes                       100000 non-null  int64
#  2   idade                     100000 non-null  float64
#  3   profissao                 100000 non-null  object
#  4   salario_anual             100000 non-null  float64
#  5   num_contas                100000 non-null  float64
#  6   num_cartoes               100000 non-null  float64
#  7   juros_emprestimo          100000 non-null  float64
#  8   num_emprestimos           100000 non-null  float64
#  9   dias_atraso               100000 non-null  float64
#  10  num_pagamentos_atrasados  100000 non-null  float64
#  11  num_verificacoes_credito  100000 non-null  float64
#  12  mix_credito               100000 non-null  object
# ...

# %%
# Passo 2: tratamento da base de dados para a IA
from sklearn.preprocessing import LabelEncoder

codificador = LabelEncoder()

# Transformar colunas que são texto em tags (label encoder):

# profissao 
#   engenheiro -> 0
#   medico -> 1
#   estudante -> 2...
tabela['profissao'] = codificador.fit_transform(tabela['profissao'])

# mix_credito
tabela['mix_credito'] = codificador.fit_transform(tabela['mix_credito'])

# comportamento_pagamento
tabela['comportamento_pagamento'] = codificador.fit_transform(tabela['comportamento_pagamento'])

# %%
# x é quem a gente usa para prever
# y é o que a gente quer prever
x = tabela.drop(columns=['score_credito', 'id_cliente'])
y = tabela['score_credito']

from sklearn.model_selection import train_test_split

# Divisão da base de dados de treino e teste

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.3) 
# 70% para treino e 30% para teste; test_size=0.3
# A ordem que as variaviess são passadas define seus significados

# %%
# Passo 3: Criar Modelo de IA: Previsão de Score de Crédito.
# Arvore de decisão (Random Forest);
# K-Nearest Neighbors (KNN).

# Para usar um IA há 3 passos:

# 1. Importar o modelo de IA
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# 2. Criar modelo de IA
modelo_arvore = RandomForestClassifier()
modelo_knn = KNeighborsClassifier()

# 3. Treinar modelo de IA.
modelo_arvore.fit(x_treino, y_treino)
modelo_knn.fit(x_treino, y_treino)
# Out:
# KNeighborsClassifier()

# %%
# Passo 4: Escolher o melhor modelo
previsao_arvore = modelo_arvore.predict(x_teste)
previsao_knn = modelo_knn.predict(x_teste)

from sklearn.metrics import accuracy_score
display(accuracy_score(y_teste, previsao_arvore))
display(accuracy_score(y_teste, previsao_knn))
# Out:
# 0.8248
# 0.7361333333333333

# %%
# Passo 5: Usar o melhor modelo de IA
# 1. Novos clientes
tabela_novos_clientes = pd.read_csv('novos_clientes.csv')

# 2. Ajustar a base de dados
tabela_novos_clientes['profissao'] = codificador.fit_transform(tabela_novos_clientes['profissao'])
tabela_novos_clientes['mix_credito'] = codificador.fit_transform(tabela_novos_clientes['mix_credito'])
tabela_novos_clientes['comportamento_pagamento'] = codificador.fit_transform(tabela_novos_clientes['comportamento_pagamento'])

# 3. Prever o score de crédito com a Arvore de Decisão 
# previsao_score_credito = modelo_arvore.predict(tabela_novos_clientes.drop(columns=['id_cliente']))
previsao_score_credito = modelo_arvore.predict(tabela_novos_clientes)
from sklearn.metrics import accuracy_score
display(previsao_score_credito)
# Out:
# array(['Poor', 'Good', 'Good'], dtype=object)
